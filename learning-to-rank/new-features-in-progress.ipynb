# %%
datasets = [
    'longeval-train-20230513-training', 
    'longeval-heldout-20230513-training',
    'longeval-2023-01-20240423-training',
    'longeval-2023-06-20240418-training',
    'longeval-2023-08-20240418-training',
    'longeval-short-july-20230513-training',
    'longeval-long-september-20230513-training',
]

query_document_scores = [

# Running:
# https://www.tira.io/submit/ir-benchmarks/user/fschlatt/upload-submission
    #'fschlatt/rank-zephyr',

    'tira-ir-starter/PL2 Re-Rank (tira-ir-starter-pyterrier)',
    'tira-ir-starter/DirichletLM Re-Rank (tira-ir-starter-pyterrier)',
    'tira-ir-starter/DLH Re-Rank (tira-ir-starter-pyterrier)',
    'fschlatt/sparse-cross-encoder-4-512',
    'fschlatt/castorini-list-in-t5-150',
    'tira-ir-starter/SBERT multi-qa-mpnet-base-cos-v1 (tira-ir-starter-beir)',
    'tira-ir-starter/MonoT5 Base (tira-ir-starter-gygaggle)',
    'tira-ir-starter/ColBERT Re-Rank (tira-ir-starter-pyterrier)',
    'tira-ir-starter/ANCE Base Cosine (tira-ir-starter-beir)',
    'tira-ir-starter/BM25 Re-Rank (tira-ir-starter-pyterrier)',
    
    
    'tira-ir-starter/LGD Re-Rank (tira-ir-starter-pyterrier)',


    'qpptk/all-predictors',

    'dossier/pre-retrieval-query-intent',
    'fschlatt/query-health-classification',

    'fschlatt/document-health-classification',
    'tu-dresden-01/genre-mlp',
    'tu-dresden-04/spacy-document-features',
]

# %%
from tira.rest_api_client import Client

tira = Client()

# %%
for dataset in datasets:
    for approach in query_document_scores:
        print(approach, dataset)
        print(tira.get_run_output('ir-benchmarks/' + approach, dataset))
# Out:
# tira-ir-starter/PL2 Re-Rank (tira-ir-starter-pyterrier) longeval-train-20230513-training
# /root/.tira/extracted_runs/ir-benchmarks/longeval-train-20230513-training/tira-ir-starter/2024-04-21-06-40-06/output
# tira-ir-starter/DirichletLM Re-Rank (tira-ir-starter-pyterrier) longeval-train-20230513-training
# /root/.tira/extracted_runs/ir-benchmarks/longeval-train-20230513-training/tira-ir-starter/2024-04-21-06-45-49/output
# tira-ir-starter/DLH Re-Rank (tira-ir-starter-pyterrier) longeval-train-20230513-training
# /root/.tira/extracted_runs/ir-benchmarks/longeval-train-20230513-training/tira-ir-starter/2024-04-21-07-26-06/output
# fschlatt/sparse-cross-encoder-4-512 longeval-train-20230513-training
# /root/.tira/extracted_runs/ir-benchmarks/longeval-train-20230513-training/fschlatt/2024-04-19-14-24-12/output
# fschlatt/castorini-list-in-t5-150 longeval-train-20230513-training
# ...
